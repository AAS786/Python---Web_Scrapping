# %% [markdown]
# <a id="1"></a>
# # <p style="padding:10px;background-color:#686868;margin:0;color:#c6b9be;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Web_Scrapping</p>

# %% [markdown]
# ![b8a40d8a-4fe9-4980-aec0-11dc4c7192a6.jfif](attachment:b8a40d8a-4fe9-4980-aec0-11dc4c7192a6.jfif)

# %% [markdown]
# <a id="1"></a>
# # <p style="padding:10px;background-color:#686868;margin:0;color:#c6b9be;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">On Smart TV</p>

# %% [markdown]
# <a id="1"></a>
# # <p style="padding:10px;background-color:#d5eae9;margin:0;color:#c27849;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Import Libraries</p>

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# <a id="1"></a>
# #### <p style="padding:5px;background-color:#d5eae9;margin:0;color:#c27849;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 50px 50px;overflow:hidden;font-weight:200">Import URL</p>

# %%
url = "https://www.flipkart.com/search?q=tv+smart+tv&sid=ckf%2Cczl&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_2_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_2_na_na_na&as-pos=1&as-type=RECENT&suggestionId=tv+smart+tv%7CTelevisions&requestId=cad0b3c1-03cd-41d2-bf93-f3ac610e4fe5&as-searchtext=tv+smart+tv&p%5B%5D=facets.brand%255B%255D%3DSAMSUNG&p%5B%5D=facets.brand%255B%255D%3DSONY&p%5B%5D=facets.brand%255B%255D%3DLG&p%5B%5D=facets.brand%255B%255D%3DMOTOROLA&p%5B%5D=facets.brand%255B%255D%3DMi&page=1"

# %%
r = requests.get(url)
print(r)
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(r.text, "lxml")

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# ...

# %%
np = soup.find("a",class_="_1LKTO3").get("href")
print(np)
# Out:
# /search?q=tv+smart+tv&sid=ckf%2Cczl&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_2_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_2_na_na_na&as-pos=1&as-type=RECENT&suggestionId=tv+smart+tv%7CTelevisions&requestId=cad0b3c1-03cd-41d2-bf93-f3ac610e4fe5&as-searchtext=tv+smart+tv&p%5B%5D=facets.brand%255B%255D%3DSAMSUNG&p%5B%5D=facets.brand%255B%255D%3DSONY&p%5B%5D=facets.brand%255B%255D%3DLG&p%5B%5D=facets.brand%255B%255D%3DMOTOROLA&p%5B%5D=facets.brand%255B%255D%3DMi&page=2

# %%
cnp = "https://www.flipkart.com"+np
print(cnp)
# Out:
# https://www.flipkart.com/search?q=tv+smart+tv&sid=ckf%2Cczl&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_2_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_2_na_na_na&as-pos=1&as-type=RECENT&suggestionId=tv+smart+tv%7CTelevisions&requestId=cad0b3c1-03cd-41d2-bf93-f3ac610e4fe5&as-searchtext=tv+smart+tv&p%5B%5D=facets.brand%255B%255D%3DSAMSUNG&p%5B%5D=facets.brand%255B%255D%3DSONY&p%5B%5D=facets.brand%255B%255D%3DLG&p%5B%5D=facets.brand%255B%255D%3DMOTOROLA&p%5B%5D=facets.brand%255B%255D%3DMi&page=2

# %%
url = cnp
r = requests.get(url)

# %%
soup = BeautifulSoup(r.text,"lxml")
box = soup.find("div",class_="_1YokD2 _3Mn1Gg")

# %% [markdown]
# <a id="1"></a>
# #### <p style="padding:8px;background-color:#d5eae9;margin:0;color:#c27849;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 70px 60px;overflow:hidden;font-weight:200">Import Data in Loop</p>

# %% [markdown]
# # all page in one loop

# %% [markdown]
# ### It will only work if u have different link in pages of other for.e.g click on next page

# %% [markdown]
# # For loop

# %%
for i in range(2,15):
     url = "https://www.flipkart.com/search?q=tv+smart+tv&sid=ckf%2Cczl&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_2_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_2_na_na_na&as-pos=1&as-type=RECENT&suggestionId=tv+smart+tv%7CTelevisions&requestId=cad0b3c1-03cd-41d2-bf93-f3ac610e4fe5&as-searchtext=tv+smart+tv&p%5B%5D=facets.brand%255B%255D%3DSAMSUNG&p%5B%5D=facets.brand%255B%255D%3DSONY&p%5B%5D=facets.brand%255B%255D%3DLG&p%5B%5D=facets.brand%255B%255D%3DMOTOROLA&p%5B%5D=facets.brand%255B%255D%3DMi&page="+str(i)
     r = requests.get(url)
     #print(r)
     soup = BeautifulSoup(r.text,"lxml")
     np = soup.find("a",class_="_1LKTO3").get("href")
     cnp = "https://www.flipkart.com"+np
     print(cnp)
# Out:
# https://www.flipkart.com/search?q=tv+smart+tv&sid=ckf%2Cczl&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_2_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_2_na_na_na&as-pos=1&as-type=RECENT&suggestionId=tv+smart+tv%7CTelevisions&requestId=cad0b3c1-03cd-41d2-bf93-f3ac610e4fe5&as-searchtext=tv+smart+tv&p%5B%5D=facets.brand%255B%255D%3DSAMSUNG&p%5B%5D=facets.brand%255B%255D%3DSONY&p%5B%5D=facets.brand%255B%255D%3DLG&p%5B%5D=facets.brand%255B%255D%3DMOTOROLA&p%5B%5D=facets.brand%255B%255D%3DMi&page=1
# ...

# %% [markdown]
# <a id="1"></a>
# #### <p style="padding:8px;background-color:#d5eae9;margin:0;color:#c27849;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 70px 60px;overflow:hidden;font-weight:200">Inspect Data on Website</p>

# %%
url = "https://www.flipkart.com/search?q=tv+smart+tv&sid=ckf%2Cczl&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_2_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_2_na_na_na&as-pos=1&as-type=RECENT&suggestionId=tv+smart+tv%7CTelevisions&requestId=cad0b3c1-03cd-41d2-bf93-f3ac610e4fe5&as-searchtext=tv+smart+tv&p%5B%5D=facets.brand%255B%255D%3DSAMSUNG&p%5B%5D=facets.brand%255B%255D%3DSONY&p%5B%5D=facets.brand%255B%255D%3DLG&p%5B%5D=facets.brand%255B%255D%3DMOTOROLA&p%5B%5D=facets.brand%255B%255D%3DMi&page=1"
r = requests.get(url)
#print(r)
soup = BeautifulSoup(r.text,"lxml")

# %% [markdown]
# <a id="1"></a>
# # <p style="padding:10px;background-color:#254441;margin:0;color:#c27849;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">TITLE OF THE PRODUCT</p>

# %%
title=soup.title
title
# Out:
# <title>Tv Smart Tv- Buy Products Online at Best Price in India - All Categories | Flipkart.com</title>

# %%
Product_name = []
Prices = []
Description = []
Reviews = []

# %% [markdown]
# # 1) a) Get the Name of the Products

# %%
names =soup.find_all("div",class_="_4rR01T")
names = box.find_all("div",class_="_4rR01T")
print(names)
# Out:
# [<div class="_4rR01T">SAMSUNG Crystal Vision 4K iSmart with Voice Assistant 138 cm (55 inch) Ultra HD (4K) LED Smart Tizen T...</div>, <div class="_4rR01T">LG UQ7550 108 cm (43 inch) Ultra HD (4K) LED Smart WebOS TV 2023 Edition with a5 Gen5 AI Processor 4K,...</div>, <div class="_4rR01T">MOTOROLA 80 cm (32 inch) HD Ready LED Smart Google TV</div>, <div class="_4rR01T">MOTOROLA EnvisionX 140 cm (55 inch) QLED Ultra HD (4K) Smart Google TV with Dolby Vision and Dolby Atm...</div>, <div class="_4rR01T">SAMSUNG 108 cm (43 inch) Full HD LED Smart Tizen TV 2023 Edition</div>, <div class="_4rR01T">MOTOROLA EnvisionX 102 cm (40 inch) Full HD LED Smart Google TV with Inbuilt Box Speakers</div>, <div class="_4rR01T">MOTOROLA EnvisionX 109 cm (43 inch) Full HD LED Smart Google TV with Inbuilt Box Speakers</div>, <div class="_4rR01T">Mi X Pro 108 cm (43 inch) Ultra HD (4K) LED Smart Google TV 2023 Edition with 4K Dolby Vision IQ | HDR...</div>, <div class="_4rR01T">MOTOROLA EnvisionX 165 cm (65
# ...

# %% [markdown]
# # b) Get the Name of the Products in list

# %%
for i in names:
    name = i.text
    Product_name.append(name)
print(Product_name)
# Out:
# ['SAMSUNG Crystal Vision 4K iSmart with Voice Assistant 138 cm (55 inch) Ultra HD (4K) LED Smart Tizen T...', 'LG UQ7550 108 cm (43 inch) Ultra HD (4K) LED Smart WebOS TV 2023 Edition with a5 Gen5 AI Processor 4K,...', 'MOTOROLA 80 cm (32 inch) HD Ready LED Smart Google TV', 'MOTOROLA EnvisionX 140 cm (55 inch) QLED Ultra HD (4K) Smart Google TV with Dolby Vision and Dolby Atm...', 'SAMSUNG 108 cm (43 inch) Full HD LED Smart Tizen TV 2023 Edition', 'MOTOROLA EnvisionX 102 cm (40 inch) Full HD LED Smart Google TV with Inbuilt Box Speakers', 'MOTOROLA EnvisionX 109 cm (43 inch) Full HD LED Smart Google TV with Inbuilt Box Speakers', 'Mi X Pro 108 cm (43 inch) Ultra HD (4K) LED Smart Google TV 2023 Edition with 4K Dolby Vision IQ | HDR...', 'MOTOROLA EnvisionX 165 cm (65 inch) Ultra HD (4K) LED Smart Google TV with Inbuilt Box Speakers', 'LG UQ7550 139 cm (55 inch) Ultra HD (4K) LED Smart WebOS TV 2023 Edition with a5 Gen5 AI Processor 4K,...', 'Mi X Pro 138 cm (55 inch) Ultra HD (4K) L
# ...

# %%
print(len(Product_name))
# Out:
# 24

# %% [markdown]
# # 2) a) Get the Price of the Products

# %%
prices = soup.find_all("div",class_="_30jeq3 _1_WHN1")
prices = box.find_all("div",class_="_30jeq3 _1_WHN1")

# %% [markdown]
# # b) Get the Price of the Products in list

# %%
for i in prices:
    name = i.text
    Prices.append(name)
print(Prices)
# Out:
# ['₹44,990', '₹33,990', '₹10,999', '₹30,999', '₹26,990', '₹17,999', '₹19,999', '₹32,999', '₹39,999', '₹46,990', '₹47,999', '₹63,640', '₹36,999', '₹41,999', '₹44,990', '₹24,999', '₹29,999', '₹22,999', '₹43,990', '₹16,999', '₹10,999', '₹67,990', '₹22,999', '₹41,999']

# %%
print(len(Prices))
# Out:
# 24

# %% [markdown]
# # 3) a) Get the Description of the Products

# %%
desc = soup.find_all("ul",class_="_1xgFaf")

# %% [markdown]
# # b) Get the Description of the Products in list

# %%
for i in desc:
    name = i.text
    Description.append(name)
print(Description)
# Out:
# ['Operating System: Google TVHD Ready 1366 x 768 PixelsLaunch Year: 20231 Year Warranty', 'Operating System: Google TVUltra HD (4K) 3840 x 2160 PixelsLaunch Year: 20231 Year Warranty', 'Operating System: Google TVFull HD 1920 x 1080 PixelsLaunch Year: 20231 Year Warranty', "Operating System: WebOSHD Ready 1366 x 768 PixelsLaunch Year: 20201 Year Product Warranty Applicable from the 1st Feb - 29th Feb'24", 'Operating System: Google TVHD Ready 1366 x 768 PixelsLaunch Year: 20231 Year Warranty on Product and 2 Years Warranty on Panel', 'Operating System: TizenHD Ready 1366 x 768 PixelsLaunch Year: 20221 Year Comprehensive Warranty on Product and 1 Year Additional on Panel', 'Operating System: Google TVUltra HD (4K) 3840 x 2160 PixelsLaunch Year: 20231 Year Warranty on Product and 2 Years Warranty on Panel', 'Operating System: AndroidUltra HD (4K) 3840 x 2160 PixelsLaunch Year: 20221 Year Warranty on Product and 2 Years Warranty on Panel OEM Warranty activation starts from the date of de
# ...

# %%
print(len(Description))
# Out:
# 24

# %% [markdown]
# # 4) a) Get the Reviews of the Products

# %%
reviews = soup.find_all("div",class_="_3LWZlK")
reviews = box.find_all("div",class_="_3LWZlK")

# %% [markdown]
# # b) Get the Reviews of the Products in list

# %%
for i in reviews:
    name = i.text
    Reviews.append(name)
print(Reviews)
# Out:
# ['4.4', '4.4', '4.2', '4.3', '4.4', '4.2', '4.2', '4.3', '4.3', '4.4', '4.3', '4.6', '4.3', '4.3', '4.4', '4.6', '4.3', '4.3', '4.4', '4.3', '4.2', '4.4', '4.4', '4.3']

# %%
print(len(Reviews))
# Out:
# 24

# %% [markdown]
# # Extra Info

# %% [markdown]
# #### if you get to many reviews in 1 page except model than use below code:-

# %% [raw]
# # After Soup
# box = soup.find_all("div"class_="_1YokD2 _3Mn1Gg")
# names = box.find_all("div",class_="_4rR01T")
# print(names)
# prices = box.find_all("div",class_="_30jeq3 _1_WHN1")
# reviews = box.find_all("div",class_="_3LWZlK")

# %% [markdown]
# <a id="1"></a>
# # <p style="padding:10px;background-color:#686868;margin:0;color:#c6b9be;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Put all data in DataFrame</p>

# %%
df = pd.DataFrame({"Product_name":Product_name,"Prices":Prices,"Description":Description,"Reviews": Reviews})

# %%
df
# Out:
#                                          Product_name   Prices  \
# 0   SAMSUNG Crystal Vision 4K iSmart with Voice As...  ₹44,990
# 1   LG UQ7550 108 cm (43 inch) Ultra HD (4K) LED S...  ₹33,990
# 2   MOTOROLA 80 cm (32 inch) HD Ready LED Smart Go...  ₹10,999
# 3   MOTOROLA EnvisionX 140 cm (55 inch) QLED Ultra...  ₹30,999
# 4   SAMSUNG 108 cm (43 inch) Full HD LED Smart Tiz...  ₹26,990
# 5   MOTOROLA EnvisionX 102 cm (40 inch) Full HD LE...  ₹17,999
# 6   MOTOROLA EnvisionX 109 cm (43 inch) Full HD LE...  ₹19,999
# 7   Mi X Pro 108 cm (43 inch) Ultra HD (4K) LED Sm...  ₹32,999
# 8   MOTOROLA EnvisionX 165 cm (65 inch) Ultra HD (...  ₹39,999
# 9   LG UQ7550 139 cm (55 inch) Ultra HD (4K) LED S...  ₹46,990
# 10  Mi X Pro 138 cm (55 inch) Ultra HD (4K) LED Sm...  ₹47,999
# 11  SONY Bravia X75L 138.8 cm (55 inch) Ultra HD (...  ₹63,640
# 12  Mi X Series 138 cm (55 inch) Ultra HD (4K) LED...  ₹36,999
# 13  MOTOROLA EnvisionX 165 cm (65 inch) QLED Ultra...  ₹41,999
# ...

# %% [markdown]
# # put all data into Excel file in same python programming file

# %%
df.to_csv("Fipkart_Smart_TV.csv")

# %% [markdown]
# # Multiple pages in one DataFrame

# %%
# Loop through pages
for i in range(2, 4):
    url = "https://www.flipkart.com/search?q=tv+smart+tv&sid=ckf%2Cczl&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_2_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_2_na_na_na&as-pos=1&as-type=RECENT&suggestionId=tv+smart+tv%7CTelevisions&requestId=cad0b3c1-03cd-41d2-bf93-f3ac610e4fe5&as-searchtext=tv+smart+tv&p%5B%5D=facets.brand%255B%255D%3DSAMSUNG&p%5B%5D=facets.brand%255B%255D%3DSONY&p%5B%5D=facets.brand%255B%255D%3DLG&p%5B%5D=facets.brand%255B%255D%3DMOTOROLA&p%5B%5D=facets.brand%255B%255D%3DMi&page=" + str(i)
    r = requests.get(url)
    soup = BeautifulSoup(r.text, "html.parser")

    # Extract product names
    names = soup.find_all("div", class_="_4rR01T")
    names = box.find_all("div",class_="_4rR01T")
    for name in names:
        Product_name.append(name.text.strip())

    # Extract prices
    prices = soup.find_all("div", class_="_30jeq3 _1_WHN1")
    prices = box.find_all("div",class_="_30jeq3 _1_WHN1")
    for price in prices:
        Prices.append(price.text.strip())

    # Extract descriptions
    descs = soup.find_all("ul", class_="_1xgFaf")
    for desc in descs:
        Description.append(desc.text.strip())

    # Extract reviews
    reviews = soup.find_all("div", class_="_3LWZlK")
    reviews = box.find_all("div",class_="_3LWZlK")
    for review in reviews:
        Reviews.append(review.text.strip())

# Print or further process the collected data
print("Product Names:", Product_name)
print("Prices:", Prices)
print("Descriptions:", Description)
print("Reviews:", Reviews)
# Out:
# Product Names: ['SAMSUNG Crystal Vision 4K iSmart with Voice Assistant 138 cm (55 inch) Ultra HD (4K) LED Smart Tizen T...', 'LG UQ7550 108 cm (43 inch) Ultra HD (4K) LED Smart WebOS TV 2023 Edition with a5 Gen5 AI Processor 4K,...', 'MOTOROLA 80 cm (32 inch) HD Ready LED Smart Google TV', 'MOTOROLA EnvisionX 140 cm (55 inch) QLED Ultra HD (4K) Smart Google TV with Dolby Vision and Dolby Atm...', 'SAMSUNG 108 cm (43 inch) Full HD LED Smart Tizen TV 2023 Edition', 'MOTOROLA EnvisionX 102 cm (40 inch) Full HD LED Smart Google TV with Inbuilt Box Speakers', 'MOTOROLA EnvisionX 109 cm (43 inch) Full HD LED Smart Google TV with Inbuilt Box Speakers', 'Mi X Pro 108 cm (43 inch) Ultra HD (4K) LED Smart Google TV 2023 Edition with 4K Dolby Vision IQ | HDR...', 'MOTOROLA EnvisionX 165 cm (65 inch) Ultra HD (4K) LED Smart Google TV with Inbuilt Box Speakers', 'LG UQ7550 139 cm (55 inch) Ultra HD (4K) LED Smart WebOS TV 2023 Edition with a5 Gen5 AI Processor 4K,...', 'Mi X Pro 138 cm (55 inch) 
# ...

# %%
print(len( Product_name))
print(len(Prices))
print(len(Description))
print(len(Reviews))
# Out:
# 72
# 72
# 72
# 72

# %%
df = pd.DataFrame({"Product_name":Product_name,"Prices":Prices,"Description":Description,"Reviews": Reviews})
df
# Out:
#                                          Product_name   Prices  \
# 0   SAMSUNG Crystal Vision 4K iSmart with Voice As...  ₹44,990
# 1   LG UQ7550 108 cm (43 inch) Ultra HD (4K) LED S...  ₹33,990
# 2   MOTOROLA 80 cm (32 inch) HD Ready LED Smart Go...  ₹10,999
# 3   MOTOROLA EnvisionX 140 cm (55 inch) QLED Ultra...  ₹30,999
# 4   SAMSUNG 108 cm (43 inch) Full HD LED Smart Tiz...  ₹26,990
# ..                                                ...      ...
# 67  Mi 5A 80 cm (32 inch) HD Ready LED Smart Andro...  ₹16,999
# 68  MOTOROLA Envision X 80 cm (32 inch) HD Ready L...  ₹10,999
# 69  LG UR7500 164 cm (65 inch) Ultra HD (4K) LED S...  ₹67,990
# 70  Mi 5A 108 cm (43 inch) Full HD LED Smart Andro...  ₹22,999
# 71  Mi X Pro 125 cm (50 inch) Ultra HD (4K) LED Sm...  ₹41,999
#
#                                           Description Reviews
# 0   Operating System: Google TVHD Ready 1366 x 768...     4.4
# 1   Operating System: Google TVUltra HD (4K) 3840 ...     4.4
# ...

# %% [markdown]
# <a id="1"></a>
# #### <p style="padding:8px;background-color:#d5eae9;margin:0;color:#c27849;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 70px 60px;overflow:hidden;font-weight:200">Save data into your Path</p>

# %%
df.to_csv("C:/Users/dell/Desktop/all projects/Fipkart_Smart_TV_1.csv")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm

# Load data from Excel file
df
# Out:
#                                          Product_name   Prices  \
# 0   SAMSUNG Crystal Vision 4K iSmart with Voice As...  ₹44,990
# 1   LG UQ7550 108 cm (43 inch) Ultra HD (4K) LED S...  ₹33,990
# 2   MOTOROLA 80 cm (32 inch) HD Ready LED Smart Go...  ₹10,999
# 3   MOTOROLA EnvisionX 140 cm (55 inch) QLED Ultra...  ₹30,999
# 4   SAMSUNG 108 cm (43 inch) Full HD LED Smart Tiz...  ₹26,990
# ..                                                ...      ...
# 67  Mi 5A 80 cm (32 inch) HD Ready LED Smart Andro...  ₹16,999
# 68  MOTOROLA Envision X 80 cm (32 inch) HD Ready L...  ₹10,999
# 69  LG UR7500 164 cm (65 inch) Ultra HD (4K) LED S...  ₹67,990
# 70  Mi 5A 108 cm (43 inch) Full HD LED Smart Andro...  ₹22,999
# 71  Mi X Pro 125 cm (50 inch) Ultra HD (4K) LED Sm...  ₹41,999
#
#                                           Description Reviews
# 0   Operating System: Google TVHD Ready 1366 x 768...     4.4
# 1   Operating System: Google TVUltra HD (4K) 3840 ...     4.4
# ...

# %% [markdown]
# <a id="1"></a>
# # <p style="padding:10px;background-color:#254441;margin:0;color:#c27849;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Data Visualization</p>

# %% [markdown]
# <a id="1"></a>
# # <p style="padding:10px;background-color:#d5eae9;margin:0;color:#c27849;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Few More Libraries Import</p>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <a id="1"></a>
# #### <p style="padding:8px;background-color:#d5eae9;margin:0;color:#c27849;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 70px 60px;overflow:hidden;font-weight:200">Import Data in DataFrame</p>

# %%
# Create the DataFrame
data = {
    'Product_name': [
        'SAMSUNG Crystal', 'LG UQ7550', 'MOTOROLA HD Ready', 'MOTOROLA EnvisionX', 'Mi A series',
        'SAMSUNG BU8570UL', 'LG Nanocell', 'Mi 4A Horizon Edition', 'Mi X Series', 'SAMSUNG Crystal Vision'
    ],
    'Prices': [41990, 31990, 9999, 29999, 22999, 42490, 56990, 17999, 36999, 66490],
    'Description': [
        'TizenUltra HD (4K)', 'WebOSUltra HD (4K)', 'Google TVHD Ready', 'Google TVUltra HD (4K)', 'Google TVFull HD',
        'TizenUltra HD (4K)', 'WebOSUltra HD (4K)', 'AndroidHD Ready', 'AndroidUltra HD (4K)', 'TizenUltra HD (4K)'
    ],
    'Reviews': [4.4, 4.4, 4.2, 4.3, 4.3, 4.8, 4.4, 4.4, 4.3, 4.4]
}

df = pd.DataFrame(data)

# %%
df.describe()
# Out:
#              Prices    Reviews
# count     10.000000  10.000000
# mean   35794.500000   4.390000
# std    17224.021348   0.159513
# min     9999.000000   4.200000
# 25%    24749.000000   4.300000
# 50%    34494.500000   4.400000
# 75%    42365.000000   4.400000
# max    66490.000000   4.800000

# %% [markdown]
# <a id="1"></a>
# #### <p style="padding:8px;background-color:#d5eae9;margin:0;color:#c27849;font-family:newtimeroman;font-size:150%;text-align:left;border-radius: 70px 60px;overflow:hidden;font-weight:200">Box Plot</p>

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Prices', data=df)
plt.title('Box Plot - Prices')
plt.show()

# %%
Q1 = df['Reviews'].quantile(0.25)
Q2 = df['Reviews'].quantile(0.50)  # Median
Q3 = df['Reviews'].quantile(0.75)
IQR = Q3 - Q1

print(Q1)
print(Q2)
print(Q3)
print(IQR)
# Out:
# 4.3
# 4.4
# 4.4
# 0.10000000000000053

# %% [markdown]
# <a id="1"></a>
# #### <p style="padding:8px;background-color:#d5eae9;margin:0;color:#c27849;font-family:newtimeroman;font-size:150%;text-align:left;border-radius: 70px 60px;overflow:hidden;font-weight:200">Bar Chart</p>

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='Product_name', y='Prices', data=df, palette='viridis')
plt.title('Bar Chart - Prices')
plt.ylabel('Prices')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better visibility
plt.show()

# %% [markdown]
# <a id="1"></a>
# #### <p style="padding:8px;background-color:#d5eae9;margin:0;color:#c27849;font-family:newtimeroman;font-size:150%;text-align:left;border-radius: 70px 60px;overflow:hidden;font-weight:200">Scatter Plot</p>

# %%
# Example DataFrame creation
data = {
    'Product_name': ['MOTOROLA 80 cm (32 inch) HD Ready LED Smart Google TV', 'MOTOROLA EnvisionX 140 cm (55 inch) QLED Ultra HD (4K) Smart Google TV with Dolby Vision and Dolby Atm...', 'SAMSUNG 80 cm (32 Inch) HD Ready LED Smart Tizen TV 2022 Edition with Bezel-free Design', 'LG 80 cm (32 inch) HD Ready LED Smart WebOS TV', 'Mi A series 80 cm (32 inch) HD Ready LED Smart Google TV 2023 Edition with HD |Dolby Audio | DTS:HD | ...', 'LG 80 cm (32 inch) HD Ready LED Smart WebOS TV 2023 Edition with a5 AI Processor Gen5, Refresh Rate: 6...', 'MOTOROLA EnvisionX 109 cm (43 inch) Full HD LED Smart Google TV with Inbuilt Box Speakers', 'MOTOROLA EnvisionX 165 cm (65 inch) QLED Ultra HD (4K) Smart Google TV with Dolby Vision and Dolby Atm...', 'LG UR7500 108 cm (43 inch) Ultra HD (4K) LED Smart WebOS TV 2023 Edition with a5 AI Processor 4K Gen6 ...', 'SAMSUNG Crystal 4K iSmart Series 108 cm (43 inch) Ultra HD (4K) LED Smart Tizen TV 2023 Edition', 'MOTOROLA EnvisionX 140 cm (55 inch) Ultra HD (4K) LED Smart Google TV with Inbuilt Box Speakers', 'MOTOROLA EnvisionX 109 cm (43 inch) Ultra HD (4K) LED Smart Google TV with Inbuilt Box Speakers', 'Mi X Series 108 cm (43 inch) Ultra HD (4K) LED Smart Google TV 2023 Edition with 4K Dolby Vision | HDR...', 'Mi A series 100 cm (40 inch) Full HD LED Smart Google TV 2023 Edition with FHD | Dolby Audio | DTS : H...', 'Mi X Series 125 cm (50 inch) Ultra HD (4K) LED Smart Android TV 2022 Edition with 4K Dolby Vision | HD...', 'SONY Bravia 108 cm (43 inch) Ultra HD (4K) LED Smart Google TV 2022 Edition', 'SAMSUNG Crystal 4K iSmart Series 138 cm (55 inch) Ultra HD (4K) LED Smart Tizen TV 2023 Edition', 'MOTOROLA EnvisionX 127 cm (50 inch) Ultra HD (4K) LED Smart Google TV with Inbuilt Box Speakers', 'Mi X Series 125 cm (50 inch) Ultra HD (4K) LED Smart Google TV 2023 Edition with 4K Dolby Vision | HDR...', 'SAMSUNG Crystal Vision 4K iSmart with Voice Assistant 108 cm (43 inch) Ultra HD (4K) LED Smart Tizen T...', 'SONY 108 cm (43 inch) Ultra HD (4K) LED Smart Google TV 2023 Edition', 'SONY 138.8 cm (55 inch) Ultra HD (4K) LED Smart Google TV 2022 Edition', 'LG UR7500 139 cm (55 inch) Ultra HD (4K) LED Smart WebOS TV 2023 Edition with a5 AI Processor 4K Gen6 ...', 'SAMSUNG Crystal Vision 4K iSmart with Voice Assistant 138 cm (55 inch) Ultra HD (4K) LED Smart Tizen T...'],
    'Prices': ['₹9,999', '₹29,999', '₹12,490', '₹14,490', '₹12,490', '₹14,990', '₹17,999', '₹39,999', '₹29,990', '₹27,490', '₹28,999', '₹21,999', '₹25,999', '₹19,999', '₹30,999', '₹37,990', '₹42,490', '₹24,999', '₹32,999', '₹28,990', '₹40,990', '₹52,490', '₹43,990', '₹44,990'],
    'Description': ['Operating System: Google TVHD Ready 1366 x 768 PixelsLaunch Year: 20231 Year Warranty', 'Operating System: Google TVUltra HD (4K) 3840 x 2160 PixelsLaunch Year: 20231 Year Warranty', 'Operating System: TizenHD Ready 1366 x 768 PixelsLaunch Year: 20221 Year Comprehensive Warranty on Product and 1 Year Additional on Panel', "Operating System: WebOSHD Ready 1366 x 768 PixelsLaunch Year: 20201 Years Warranty*: 1 Year Product Warranty Applicable from the 1st Feb - 29th Feb'24", 'Operating System: Google TVHD Ready 1366 x 768 PixelsLaunch Year: 20231 Year Warranty on Product and 2 Years Warranty on Panel', "Operating System: WebOSHD Ready 1366 x 768 PixelsLaunch Year: 20231 Years Warranty*: 1 Year Product Warranty Applicable from the 1st Feb - 29th Feb'24", 'Operating System: Google TVFull HD 1920 x 1080 PixelsLaunch Year: 20231 Year Warranty', 'Operating System: Google TVUltra HD (4K) 3840 x 2160 PixelsLaunch Year: 20231 Year Warranty', "Operating System: WebOSUltra HD (4K) 3840 x 2160 PixelsLaunch Year: 20231 Years Warranty*: 1 Year Product Warranty Applicable from the 1st Feb - 29th Feb'24", 'Operating System: TizenUltra HD (4K) 3840 x 2160 PixelsLaunch Year: 20231 Year Comprehensive Warranty on Product and 1 Year Additional Warranty on Panel provided by the brand from the date of purchase', 'Operating System: Google TVUltra HD (4K) 3840 x 2160 PixelsLaunch Year: 20231 Year Warranty', 'Operating System: Google TVUltra HD (4K) 3840 x 2160 PixelsLaunch Year: 20231 Year Warranty', 'Operating System: Google TVUltra HD (4K) 3840 x 2160 PixelsLaunch Year: 20231 Year Warranty on Product and 2 Years Warranty on Panel', 'Operating System: Google TVFull HD 1920 x 1080 PixelsLaunch Year: 20231 Year Warranty on Product and 2 Years Warranty on Panel', 'Operating System: AndroidUltra HD (4K) 3840 x 2160 PixelsLaunch Year: 20221 Year Warranty on Product and 2 Years Warranty on Panel OEM Warranty activation starts from the date of delivery', "Operating System: Google TVUltra HD (4K) 3840 x 2160 PixelsLaunch Year: 20221 Year Comprehensive Warranty by the manufacture from the date of purchase | Contact Brand toll free number for assistance and provide product's model name and seller's details mentioned on your invoice The service center will allot you a convenient slot for the service", 'Operating System: TizenUltra HD (4K) 3840 x 2160 PixelsLaunch Year: 20232 years comprehensive warranty on product (1 year standard warranty and 1 year extended warranty provided by the brand from the date of purchase)', 'Operating System: Google TVUltra HD (4K) 3840 x 2160 PixelsLaunch Year: 20231 Year Warranty', 'Operating System: Google TVUltra HD (4K) 3840 x 2160 PixelsLaunch Year: 20231 Year Warranty on Product and 2 Years Warranty on Panel', 'Operating System: TizenUltra HD (4K) 3840 x 2160 PixelsLaunch Year: 20231 Year Comprehensive Warranty on Product and 1 Year Additional Warranty on Panel', 'Operating System: Google TVUltra HD (4K) 3840 x 2160 PixelsLaunch Year: 20231 Year Warranty on the Product', 'Operating System: Google TVUltra HD (4K) 3840 x 2160 PixelsLaunch Year: 20221 Year Comprehensive Warranty', "Operating System: WebOSUltra HD (4K) 3840 x 2160 PixelsLaunch Year: 20231 Years Warranty*: 1 Year Product Warranty Applicable from the 1st Feb - 29th Feb'24", 'Operating System: TizenUltra HD (4K) 3840 x 2160 PixelsLaunch Year: 20231 Year Comprehensive Warranty on Product and 1 Year Additional Warranty on Panel'],
    'Reviews': ['4.2', '4.3', '4.3', '4.3', '4.3', '4.3', '4.2', '4.3', '4.4', '4.3', '4.3', '4.3', '4.3', '4.3', '4.3', '4.6', '4.3', '4.3', '4.3', '4.4', '4.6', '4.6', '4.4', '4.4']
}

df = pd.DataFrame(data)

# Set up the figure size
plt.figure(figsize=(10, 6))

# Create the scatter plot
sns.scatterplot(x='Prices', y='Reviews', data=df, palette='viridis')

# Set the title of the plot
plt.title('Scatter Plot - Prices vs Reviews')

# Show the plot
plt.show()

# %% [markdown]
# <a id="1"></a>
# <p style="padding:8px;background-color:#d5eae9;margin:0;color:#c27849;font-family:newtimeroman;font-size:150%;text-align:left;border-radius: 70px 60px;overflow:hidden;font-weight:200">Pie Chart</p>

# %%
data = {
    'Product_name': ['SAMSUNG Galaxy Book 2', 'ASUS Vivobook Go 15', 'ZEBRONICS Pro Series Y', 'Acer Extensa', 'ASUS Vivobook 15', 'Lenovo Yoga Slim 6', 'HP Intel Core i3', 'Apple 2020 Macbook Air', 'HP 15s Intel Core i3', 'HP AMD Ryzen 5'],
    'Prices': [42990, 25990, 27990, 29990, 61990, 65190, 30599, 77990, 37990, 45490],
    'Description': ['Intel Core i5 Processor (11th Gen)16 GB LPDDR4', 'Intel Core i5 Processor (11th Gen)8 GB DDR4 RAM', 'Stylish & Portable Thin and Light LaptopLPDDR5', 'AMD Ryzen 3 Dual Core Processor8 GB DDR4 RAM', 'Intel Core i5 Processor (12th Gen)16 GB DDR5 RAM', 'Intel Core i5 Processor (12th Gen)16 GB LPDDR5 RAM', 'Intel Core i3 Processor (11th Gen)8 GB DDR4 RAM', 'Apple M1 Processor8 GB DDR4 RAMMac OS Operating System', 'Intel Core i3 Processor (12th Gen)8 GB DDR4 RAM', 'AMD Ryzen 5 Hexa Core Processor16 GB DDR4 RAM'],
    'Reviews': [4.3, 4.1, 4, 4.1, 3.8, 4.2, 4.1, 4.7, 4.2, 4.3]
}

df = pd.DataFrame(data)

# Sort DataFrame by 'Reviews' column in descending order
df_sorted = df.sort_values(by='Reviews', ascending=False)

# Select the top 5 rows
top_5 = df_sorted.head(5)

# Create a pie chart for the top 5 products
plt.figure(figsize=(8, 8))
plt.pie(top_5['Reviews'], labels=top_5['Product_name'], autopct='%1.1f%%', startangle=140, colors=sns.color_palette('pastel'))
plt.title('Pie Chart - Top 5 Products based on Reviews')
plt.show()

# %% [markdown]
# <a id="1"></a>
# #### <p style="padding:8px;background-color:#d5eae9;margin:0;color:#c27849;font-family:newtimeroman;font-size:150%;text-align:left;border-radius: 70px 60px;overflow:hidden;font-weight:200">Histogram</p>

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Prices'], bins=10, kde=True, color='skyblue')
plt.title('Histogram - Prices')
plt.xlabel('Prices')
plt.show()

# %% [markdown]
# <a id="1"></a>
# #### <p style="padding:8px;background-color:#d5eae9;margin:0;color:#c27849;font-family:newtimeroman;font-size:150%;text-align:left;border-radius: 70px 60px;overflow:hidden;font-weight:200">Normal Distribution</p>

# %%
# Normal Distribution Plot
plt.figure(figsize=(10, 6))
sns.histplot(df['Prices'], kde=True, stat='density', color='skyblue')
sns.kdeplot(df['Prices'], color='red')
plt.title('Normal Distribution Plot - Prices')
plt.xlabel('Prices')
plt.show()

# %% [markdown]
# <a id="1"></a>
# #### <p style="padding:8px;background-color:#d5eae9;margin:0;color:#c27849;font-family:newtimeroman;font-size:150%;text-align:left;border-radius: 70px 60px;overflow:hidden;font-weight:200">Meand and Median on Graph</p>

# %%
# Load data from Excel file
df = pd.DataFrame(data)


# Calculate mean and median
mean_value = df['Reviews'].mean()
median_value = df['Reviews'].median()

# Normal Distribution Plot with Mean and Median Lines
plt.figure(figsize=(10, 6))
sns.distplot(df['Reviews'], fit=norm, kde=False, hist_kws=dict(edgecolor="k", linewidth=2))
plt.axvline(mean_value, color='red', linestyle='dashed', linewidth=2, label=f'Mean: {mean_value:.2f}')
plt.axvline(median_value, color='green', linestyle='dashed', linewidth=2, label=f'Median: {median_value:.2f}')
plt.title('Normal Distribution Plot with Mean and Median')
plt.legend()
plt.show()

# %% [markdown]
# **Conclusion:**
#
# In this project, I performed web scraping on Flipkart to extract information about smart TVs. The web scraping process involved navigating through the Flipkart website, extracting relevant data such as product names, prices, descriptions, and customer reviews for smart TVs.
#
# Following the web scraping, I organized the extracted data into a structured format using Python and Pandas. This structured data provided insights into various smart TV models, their prices, and customer ratings.
#
# For visualization, I utilized Python libraries such as Matplotlib and Seaborn to create informative plots. A box plot was employed to visualize the distribution of prices and customer reviews among different smart TV models. Additionally, a scatter plot helped to explore the relationship between prices and customer reviews for a more detailed analysis.
#
# Overall, this project showcased the process of web scraping for data extraction and the subsequent visualization of smart TV information. The insights gained from these visualizations can assist in making informed decisions when choosing a smart TV based on factors such as price and customer satisfaction.</p>
